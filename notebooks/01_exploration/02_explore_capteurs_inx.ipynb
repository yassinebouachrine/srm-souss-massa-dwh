# %% [markdown]
# # Exploration Capteurs INX
#
# **Projet :** SRM Souss-Massa DWH
#
# ## Objectif
#
# Decrire l'objectif du notebook ici.

# %% [markdown]
# ## Imports et Configuration

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os
from pathlib import Path

# Charger les variables d'environnement
project_root = Path.cwd()
while not (project_root / '.env').exists() and project_root != project_root.parent:
    project_root = project_root.parent
load_dotenv(project_root / '.env')

# Configuration pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

print('Configuration chargee')

# %% [markdown]
# ## Connexion PostgreSQL

# %%
DB_HOST = os.getenv('POSTGRES_HOST', 'localhost')
DB_PORT = os.getenv('POSTGRES_PORT', '5432')
DB_NAME = os.getenv('POSTGRES_DB', 'srm_datawarehouse')
DB_USER = os.getenv('POSTGRES_USER', 'postgres')
DB_PASSWORD = os.getenv('POSTGRES_PASSWORD')

conn_string = f'postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}'
engine = create_engine(conn_string)

print('Connexion PostgreSQL etablie')

# %% [markdown]
# ## Traitement Principal

# %%
# Votre code ici
